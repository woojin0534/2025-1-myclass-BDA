# %% [markdown]
# <a href="https://colab.research.google.com/github/woojin0534/2025-1-myclass-BDA/blob/main/inclass/05w_B_wed_0402_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'})
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new.rename(index = {0: "x", 1: "y", 2: "z"}, inplace=True)
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     1   2    30

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1["var_mean"] = (df1["var1"] + df1["var2"]) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['var_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum  var_mean  var_sum
# 0     4     2       6       3.0     15.0
# 1     3     6       9       4.5     22.5
# 2     8     1       9       4.5     22.5

# %%
df2[["var1","var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2["var_mean"] = df2[["var1","var2"]].mean(axis=1)
df2
# Out:
#    var1  var2  my_sum  var_mean
# 0     4     2       6       3.0
# 1     3     6       9       4.5
# 2     8     1       9       4.5

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# ## MPG 연비 변수 생성

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 4.10 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(3)
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 118      hyundai      tiburon    2.0  2008    4    auto(l4)   f   20   27  r
# 42         dodge  caravan 2wd    3.3  2008    6    auto(l4)   f   17   24  r
# 176       toyota  4runner 4wd    3.4  1999    6  manual(m5)   4   15   17  r
#
#        category
# 118  subcompact
# 42      minivan
# 176         suv

# %%
mpg.cty
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int64

# %%
mpg.cty + mpg.hwy
# Out:
# 0      47
# 1      50
# 2      51
# 3      51
# 4      42
#        ..
# 229    47
# 230    50
# 231    42
# 232    44
# 233    43
# Length: 234, dtype: int64

# %%
(mpg.cty + mpg.hwy) / 2
# Out:
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
#        ...
# 229    23.5
# 230    25.0
# 231    21.0
# 232    22.0
# 233    21.5
# Length: 234, dtype: float64

# %%
mpg.total = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
# <ipython-input-30-0e68e0222155>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   mpg.total = (mpg.cty + mpg.hwy) / 2
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg['total'] = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg.total) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg.total.mean()
# Out:
# np.float64(20.14957264957265)

# %% [markdown]
# ## 조건문 활용

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# dtype: float64

# %%
mpg.total.plot.hist();

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.9 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
mpg['total'].plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total");
